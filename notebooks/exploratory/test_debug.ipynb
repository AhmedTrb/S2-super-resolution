# %%
import os

# AWS credentials
os.environ["AWS_ACCESS_KEY_ID"] = "X2CL1COB8MX6AJGYWECJ"
os.environ["AWS_SECRET_ACCESS_KEY"] = "ulr3EIIFAUJVaGT4tmhv2kSo9WnkjnaNgG7jB++s"

# S3 endpoint (non-AWS)
os.environ["AWS_S3_ENDPOINT"] = "s3-data.meso.umontpellier.fr"
os.environ["AWS_HTTPS"] = "YES"
os.environ["AWS_VIRTUAL_HOSTING"] = "FALSE"

# GDAL options
os.environ["GDAL_DISABLE_READDIR_ON_OPEN"] = "EMPTY_DIR"
os.environ["CPL_VSIL_CURL_CACHE_SIZE"] = "200000000"

# %%
# !python -m awscli configure
# Out:
# ^C

# %%
S3_PATH = "/vsis3/sentinel2/sits/2020/T31UEQ/tmp/Sentinel2_T31UEQ_TSG.tif"

with rasterio.open(S3_PATH) as src:
    n_images = src.count // 10
    W, H = src.width, src.height

    print(f"File OK — {W}×{H}px")
    print(f"Bands: {src.count}")
    print(f"Timestamps: {n_images}")
# Out:
# File OK — 10990×10989px
# Bands: 740
# Timestamps: 74

# %%
from torchgeo.models import get_model, get_weight

weights = get_weight("ResNet50_Weights.SENTINEL2_ALL_DINO")
model = get_model("resnet50", weights=weights)

model.eval()
# Out:
# Downloading: "https://hf.co/torchgeo/resnet50_sentinel2_all_dino/resolve/d7f14bf5530d70ac69d763e58e77e44dbecfec7c/resnet50_sentinel2_all_dino-d6c330e9.pth" to C:\Users\ahtrabelsi/.cache\torch\hub\checkpoints\resnet50_sentinel2_all_dino-d6c330e9.pth
# 100%|██████████| 90.1M/90.1M [00:26<00:00, 3.56MB/s]
# ResNet(
#   (conv1): Conv2d(13, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#   (act1): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
base_path = Path(r"C:\Users\ahtrabelsi\Desktop\stage\s2-super-resolution\yellowness_dataset\images_lr")

for file in base_path.iterdir():
    if file.is_file():
        filename = file.name.lower()
        
        if filename.endswith('.csv'):
            shutil.move(str(file), str(target_dirs["csv_files"] / file.name))
        elif filename.endswith('lr_mask.tif'):
            shutil.move(str(file), str(target_dirs["mask_lr"] / file.name))
        elif filename.endswith('sr_mask.tif'):
            shutil.move(str(file), str(target_dirs["mask_sr"] / file.name))
        elif filename.endswith('_lr.tif'):
            shutil.move(str(file), str(target_dirs["images_lr"] / file.name))
        elif filename.endswith('_sr.tif'):
            shutil.move(str(file), str(target_dirs["images_sr"] / file.name))

print("Dataset organization complete!")
# Out:
# Dataset organization complete!
